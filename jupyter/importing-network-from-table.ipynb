# %% [markdown]
# <a href="https://colab.research.google.com/github/cytoscape/cytoscape-automation/blob/master/for-scripters/Python/importing-network-from-table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Network From Table

# %% [markdown]
# ## Yihang Xin and Alex Pico
# ## 2021-11-16

# %% [markdown]
# In addition to importing networks in network file formats, such as sif and xgmml, Cytoscape also supports importing networks from tabular data. In this notebook, the data table represents protein-protein interaction data from a mass-spectrometry experiment.

# %% [markdown]
# # Installation
# The following chunk of code installs the `py4cytoscape` module.

# %%
# %%capture
# !python3 -m pip install python-igraph requests pandas networkx
# !python3 -m pip install py4cytoscape

# %% [markdown]
# If you are using a remote notebook environment such as Google Colab, please execute the cell below. (If you're running on your local notebook, you don't need to do that.)

# %%
import requests
exec(requests.get("https://raw.githubusercontent.com/cytoscape/jupyter-bridge/master/client/p4c_init.py").text)
IPython.display.Javascript(_PY4CYTOSCAPE_BROWSER_CLIENT_JS) # Start browser client
# Out:
# /Users/shuhanliu/anaconda3/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Requirement already satisfied: py4cytoscape in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (1.7.0)
# Requirement already satisfied: pandas in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (1.5.3)
# Requirement already satisfied: networkx in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (2.8.4)
# Requirement already satisfied: requests in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (2.29.0)
# Requirement already satisfied: python-igraph in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (0.10.5)
# Requirement already satisfied: colorbrewer in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (0.2.0)
# Requirement already satisfied: chardet in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (4.0.0)
# Requirement already satisfied: decorator in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (5.1.1)
# Requirement already satisfied: backoff in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (2.2.1)
# Requirement already satisfied: colour in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from py4cytoscape) (0.1.5)
# Requirement already satisfied: six in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from colorbrewer->py4cytoscape) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from pandas->py4cytoscape) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from pandas->py4cytoscape) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from pandas->py4cytoscape) (1.24.3)
# Requirement already satisfied: igraph==0.10.5 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from python-igraph->py4cytoscape) (0.10.5)
# Requirement already satisfied: texttable>=1.6.2 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from igraph==0.10.5->python-igraph->py4cytoscape) (1.6.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from requests->py4cytoscape) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from requests->py4cytoscape) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from requests->py4cytoscape) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shuhanliu/anaconda3/lib/python3.11/site-packages (from requests->py4cytoscape) (2023.5.7)
# Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# Unable to revert mtime: /Library/Fonts
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# Failed to extract font properties from /System/Library/Fonts/LastResort.otf: tuple indices must be integers or slices, not str
# Failed to extract font properties from /System/Library/Fonts/Apple Color Emoji.ttc: In FT2Font: Could not set the fontsize (invalid pixel size; error code 0x17)
# Failed to extract font properties from /System/Library/Fonts/Supplemental/NISC18030.ttf: In FT2Font: Could not set the fontsize (invalid pixel size; error code 0x17)
# generated new fontManager
# Loading Javascript client ... 6108da5e-e09d-4a20-b962-dd54025645a0 on https://jupyter-bridge.cytoscape.org

# %% [markdown]
# # Prerequisites
# In addition to this package (py4cytoscape version 0.0.11), you will need:
#
# * Latest version of Cytoscape, which can be downloaded from https://cytoscape.org/download.html. Simply follow the installation instructions on screen.
#
# * Complete installation wizard
#
# * Launch Cytoscape
#
# You can also install app inside Python notebook by running "py4cytoscape.install_app('Your App')"

# %% [markdown]
# # Import the required package¶

# %%
import os
import sys
import pandas as pd
import py4cytoscape as p4c

# %% [markdown]
# # Setup Cytoscape

# %%
p4c.cytoscape_version_info()
# Out:
# {'apiVersion': 'v1',
#  'cytoscapeVersion': '3.9.1',
#  'automationAPIVersion': '1.7.0',
#  'py4cytoscapeVersion': '1.7.0'}

# %% [markdown]
# # Background
# The data used for this protocol represents interactions between human and HIV proteins by Jäger et al (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3310911/). In this quantitative AP-MS experiment, a relatively small number of bait proteins were used to pull down a larger set of prey proteins.

# %% [markdown]
# # Import Network

# %% [markdown]
# First we need to read in the example data file:

# %%
gu_core_data = pd.read_table("/Users/shuhanliu/Downloads/individual_project/PlaqueMS_data/PlaqueMS_data/Networks/gu_core_filtered_directed_network.txt")

# %%
gu_core_data.head()
# Out:
#   Regulator Target        MI        pvalue  directionality
# 0     SFRP2   ITB1  0.310470  4.063898e-02       -0.050244
# 1      TRFE   IGKC  0.406766  2.180235e-07        0.324126
# 2     FBLN1   SAA1  0.241169  2.924214e-03        0.192902
# 3     ANXA6   LRP1  0.396194  4.063898e-02        0.017116
# 4      SAA4  RARR2  0.293181  4.063898e-02        0.047233

# %% [markdown]
# Now we can create a data frame for the network edges (interactions) using the imported data. We can also add the AP-MS score from the data as an edge attribute:

# %%
edge_data = {'source':gu_core_data["Regulator"],
             'target':gu_core_data["Target"],
             'MI':gu_core_data["MI"],
             'pvalue':gu_core_data["pvalue"],
             'directionality':gu_core_data["directionality"]
            }
edges = pd.DataFrame(data=edge_data, columns=['source', 'target','MI','pvalue','directionality'])
edges.head()
# Out:
#   source target        MI        pvalue  directionality
# 0  SFRP2   ITB1  0.310470  4.063898e-02       -0.050244
# 1   TRFE   IGKC  0.406766  2.180235e-07        0.324126
# 2  FBLN1   SAA1  0.241169  2.924214e-03        0.192902
# 3  ANXA6   LRP1  0.396194  4.063898e-02        0.017116
# 4   SAA4  RARR2  0.293181  4.063898e-02        0.047233

# %% [markdown]
# Finally, we use the edge data fram to create the network. Note that we don’t need to define a data frame for nodes, as all nodes in this case are represented in the edge data frame.

# %%
p4c.create_network_from_data_frames(edges=edges, title='gu_core network', collection="gu_core collection")
# Out:
# Applying default style...
# Applying preferred layout
# 89824

# %%
p4c.get_table_columns()
# Out:
#         SUID shared name     id   name  selected
# 90113  90113       HPLN1  HPLN1  HPLN1     False
# 90626  90626       IGHG4  IGHG4  IGHG4     False
# 90629  90629       ANXA1  ANXA1  ANXA1     False
# 90116  90116       LG3BP  LG3BP  LG3BP     False
# 90119  90119       CO4A2  CO4A2  CO4A2     False
# ...      ...         ...    ...    ...       ...
# 90104  90104        CFAB   CFAB   CFAB     False
# 90107  90107        LEG1   LEG1   LEG1     False
# 90620  90620        TSP1   TSP1   TSP1     False
# 90623  90623         C1R    C1R    C1R     False
# 90110  90110        FIBG   FIBG   FIBG     False
#
# [290 rows x 5 columns]

# %% [markdown]
# The imported network consists of multiple smaller subnetworks, each representing a bait node and its associated prey nodes.

# %% [markdown]
# 下面开始拼接log2FC的数据

# %%
gu_core_CalcifiedVSNon_calcified_data = pd.read_table("/Users/shuhanliu/Downloads/individual_project/PlaqueMS_data/PlaqueMS_data/Statistics/diff_exp_resultsCalcifiedVSNon-calcified_gu_core.txt",index_col=0)
gu_core_CalcifiedVSNon_calcified_data.head()
# Out:
#           logFC      CI.L      CI.R   AveExpr         t   P.Value  adj.P.Val  \
# FETUA  1.556751  0.960420  2.153082  6.096402 -5.174453  0.000001   0.000328
# OSTP   1.298994  0.710850  1.887138  5.993654 -4.377802  0.000028   0.004291
# CERU  -0.737408 -1.100480 -0.374336  6.605667  4.025763  0.000106   0.008182
# APOC2  0.764442  0.379058  1.149826  6.588996 -3.931726  0.000149   0.008182
# COLA1  0.602471  0.298252  0.906690  6.361054 -3.925384  0.000153   0.008182
#
#               B  Unnamed: 9
# FETUA  5.331106         NaN
# OSTP   2.308815         NaN
# CERU   1.082575         NaN
# APOC2  0.767583         NaN
# COLA1  0.746535         NaN

# %%
df_dict = {'logFC':gu_core_CalcifiedVSNon_calcified_data["logFC"],
             'CI.L':gu_core_CalcifiedVSNon_calcified_data["CI.L"],
             'CI.R':gu_core_CalcifiedVSNon_calcified_data["CI.R"],
             'AveExpr':gu_core_CalcifiedVSNon_calcified_data["AveExpr"],
             't':gu_core_CalcifiedVSNon_calcified_data["t"],
           'P.Value':gu_core_CalcifiedVSNon_calcified_data["P.Value"],
             'adj.P.Val':gu_core_CalcifiedVSNon_calcified_data["adj.P.Val"],
           'B':gu_core_CalcifiedVSNon_calcified_data["B"]
            }
df = pd.DataFrame(data=df_dict, columns=['logFC','CI.L','CI.R','AveExpr','t', 'P.Value','adj.P.Val','B'])
df.head()
# Out:
#           logFC      CI.L      CI.R   AveExpr         t   P.Value  adj.P.Val  \
# FETUA  1.556751  0.960420  2.153082  6.096402 -5.174453  0.000001   0.000328
# OSTP   1.298994  0.710850  1.887138  5.993654 -4.377802  0.000028   0.004291
# CERU  -0.737408 -1.100480 -0.374336  6.605667  4.025763  0.000106   0.008182
# APOC2  0.764442  0.379058  1.149826  6.588996 -3.931726  0.000149   0.008182
# COLA1  0.602471  0.298252  0.906690  6.361054 -3.925384  0.000153   0.008182
#
#               B
# FETUA  5.331106
# OSTP   2.308815
# CERU   1.082575
# APOC2  0.767583
# COLA1  0.746535

# %%
p4c.load_table_data(df)
# Out:
# /Users/shuhanliu/anaconda3/lib/python3.11/site-packages/py4cytoscape/tables.py:485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset[col] = col_val
# 'Success: Data loaded in defaultnode table'

# %%
p4c.get_table_columns()
# Out:
#         SUID shared name     id   name  selected     logFC      CI.L  \
# 90113  90113       HPLN1  HPLN1  HPLN1     False  0.084057 -0.263428
# 90626  90626       IGHG4  IGHG4  IGHG4     False -0.436433 -0.763791
# 90629  90629       ANXA1  ANXA1  ANXA1     False -0.015234 -0.245899
# 90116  90116       LG3BP  LG3BP  LG3BP     False -0.426231 -0.775095
# 90119  90119       CO4A2  CO4A2  CO4A2     False  0.356603  0.021515
# ...      ...         ...    ...    ...       ...       ...       ...
# 90104  90104        CFAB   CFAB   CFAB     False -0.308860 -0.553196
# 90107  90107        LEG1   LEG1   LEG1     False  0.008214 -0.349820
# 90620  90620        TSP1   TSP1   TSP1     False  0.060086 -0.266739
# 90623  90623         C1R    C1R    C1R     False -0.162295 -0.442498
# 90110  90110        FIBG   FIBG   FIBG     False  0.393752 -0.247319
#
#            CI.R   AveExpr         t   P.Value  adj.P.Val         B row.names
# 90113  0.431542  5.576715 -0.479479  0.632565   0.794564 -6.113795     HPLN1
# 90626 -0.109075  6.475532  2.642576  0.009448   0.069512 -2.945488     IGHG4
# 90629  0.215432  6.482024  0.130906  0.896093   0.953087 -6.216917     ANXA1
# 90116 -0.077367  6.033263  2.421710  0.017110   0.096128 -3.456676     LG3BP
# 90119  0.691692  6.162156 -2.109397  0.037217   0.147816 -4.110942     CO4A2
# ...         ...       ...       ...       ...        ...       ...       ...
# 90104 -0.064523  6.748105  2.505566  0.013715   0.084237 -3.267239      CFAB
# 90107  0.366248  6.126948 -0.045475  0.963812   0.976452 -6.224229      LEG1
# 90620  0.386911  6.519813 -0.364411  0.716263   0.854537 -6.160834      TSP1
# 90623  0.117908  6.744808  1.148061  0.253476   0.518702 -5.589659       C1R
# 90110  1.034822  6.319680 -1.217444  0.226084   0.480604 -5.511072      FIBG
#
# [290 rows x 14 columns]

# %% [markdown]
# 开始分簇
# 下面是使用log2fc变颜色的代码
# from py4cytoscape import palette_color_brewer_d_RdBu
# p4c.set_node_color_mapping(**gen_node_color_map('log2fc', palette_color_brewer_d_RdBu())

# %% [markdown]
# 此处生成了一堆cluster
# commands.commands_post('mcode cluster degreeCutoff=2 fluff=true fluffNodeDensityCutoff=0.1 haircut=true includeLoops=false kCore=2 maxDepthFromStart=100 network=current nodeScoreCutoff=0.2 scope=NETWORK')

# %%
p4c.commands.commands_post('mcode cluster degreeCutoff=2 fluff=true fluffNodeDensityCutoff=0.1 haircut=true includeLoops=false kCore=2 maxDepthFromStart=100 network=current nodeScoreCutoff=0.2 scope=NETWORK')
# Out:
# {'id': 1,
#  'parameters': {'scope': 'NETWORK',
#   'includeLoops': False,
#   'degreeCutoff': 2,
#   'kCore': 2,
#   'maxDepthFromStart': 100,
#   'nodeScoreCutoff': 0.2,
#   'haircut': True,
#   'fluff': True,
#   'fluffNodeDensityCutoff': 0.1,
#   'selectedNodes': []},
#  'clusters': [{'rank': 1,
#    'name': 'Cluster 1',
#    'score': 41.22605363984674,
#    'seedNode': 90227,
#    'nodes': [90113,
#     90497,
#     90182,
#     90122,
#     90701,
#     90062,
#     90257,
#     90389,
#     89876,
#     90710,
#     90653,
#     90524,
#     90593,
#     89891,
#     90275,
#     90473,
#     90536,
#     90602,
#     90668,
#     90608,
#     90227,
#     90674,
#     90356,
#     90041,
#     90617,
#     90296,
#     89900,
#     89933,
#     89960,
#     89966,
#     89975,
#     89993,
#     90005,
#     90026,
#     90029,
#     90089,
#     90125,
#     90137,
#     90155,
#     90170,
#     90197,
#     90221,
#     90236,
#     90281,
#     90290,
#     90302,
#     90311,
#     90317,
#     90362,
#     90374,
#     90422,
#     90440,
#     90482,
#     90491,
#     90494,
#     90509,
#     90515,
#     90548,
#     90596,
#     90599,
#     90659,
#     90695,
#     89906,
#     89918,
#     89927,
#     89945,
#     89951,
#     89972,
#     89987,
#     90047,
#     90053,
#     90119,
#     90152,
#     90158,
#     90230,
#     90239,
#     90260,
#     90272,
#     90287,
#     90326,
#     90329,
#     90347,
#     90359,
#     90386,
#     90437,
#     90458,
#     90464,
#     90470,
#     90563,
#     90566,
#     90578,
#     90605,
#     90671,
#     90692,
#     90719,
#     89882,
#     89894,
#     89897,
#     89984,
#     89996,
#     90017,
#     90020,
#     90038,
#     90071,
#     90074,
#     90077,
#     90095,
#     90101,
#     90104,
#     90107,
#     90206,
#     90224,
#     90242,
#     90245,
#     90284,
#     90365,
#     90368,
#     90383,
#     90392,
#     90443,
#     90467,
#     90476,
#     90545,
#     90569,
#     90611,
#     90614,
#     90623,
#     90632,
#     90641,
#     90644,
#     90656,
#     90665,
#     90707,
#     89861,
#     89867,
#     89909,
#     89915,
#     89921,
#     89948,
#     89963,
#     90143,
#     90173,
#     90212,
#     90308,
#     90323,
#     90344,
#     90401,
#     90431,
#     90446,
#     90449,
#     90716,
#     89870,
#     89885,
#     89888,
#     89969,
#     89978,
#     90023,
#     90116,
#     90134,
#     90146,
#     90254,
#     90299,
#     90305,
#     90488,
#     90503,
#     90560,
#     90572,
#     90635,
#     90638,
#     90677,
#     89903,
#     89957,
#     90014,
#     90059,
#     90164,
#     90188,
#     90215,
#     90251,
#     90263,
#     90377,
#     90380,
#     90452,
#     90461,
#     90512,
#     90647,
#     90698,
#     89864,
#     90002,
#     90008,
#     90080,
#     90185,
#     90278,
#     90353,
#     90410,
#     90518,
#     90056,
#     90086,
#     90335,
#     90428,
#     90527,
#     90551,
#     89879,
#     90011,
#     90320,
#     90413,
#     90554,
#     90689,
#     89942,
#     90293,
#     90128,
#     90161,
#     90167,
#     90209,
#     90332,
#     90350,
#     90371,
#     90404,
#     90419,
#     90485,
#     90533,
#     90557,
#     90581,
#     90590,
#     90620,
#     90662,
#     90065,
#     90176,
#     89873,
#     90044,
#     90233,
#     89930,
#     89954,
#     89999,
#     90098,
#     90179,
#     90338,
#     90683,
#     90314,
#     90434,
#     90455,
#     90539,
#     90542,
#     89936,
#     90035,
#     90092,
#     90140,
#     90149,
#     90218,
#     90200,
#     90341,
#     89924,
#     90269,
#     90395,
#     89990,
#     90203,
#     90479,
#     89912,
#     90584,
#     90704,
#     90032,
#     90506,
#     90521]},
#   {'rank': 2,
#    'name': 'Cluster 2',
#    'score': 38.68016194331984,
#    'seedNode': 89861,
#    'nodes': [89987,
#     90371,
#     89861,
#     90116,
#     90119,
#     89990,
#     90377,
#     90632,
#     90635,
#     90125,
#     90638,
#     90641,
#     90512,
#     90005,
#     90644,
#     90392,
#     90014,
#     90659,
#     90023,
#     90026,
#     90284,
#     90287,
#     89906,
#     90167,
#     89918,
#     90053,
#     89924,
#     90692,
#     90695,
#     90056,
#     90443,
#     90572,
#     90704,
#     90323,
#     90578,
#     89945,
#     90329,
#     90074,
#     89951,
#     90338,
#     90596,
#     90215,
#     90599,
#     90086,
#     90347,
#     90092,
#     90476,
#     90611,
#     90482,
#     90104,
#     90365,
#     90239,
#     89879,
#     89900,
#     89927,
#     89930,
#     89933,
#     89936,
#     89957,
#     89972,
#     90002,
#     90047,
#     90077,
#     90134,
#     90146,
#     90155,
#     90164,
#     90203,
#     90230,
#     90236,
#     90278,
#     90281,
#     90311,
#     90317,
#     90374,
#     90440,
#     90458,
#     90467,
#     90479,
#     90521,
#     90551,
#     90590,
#     90605,
#     89885,
#     89942,
#     89993,
#     90008,
#     90017,
#     90101,
#     90128,
#     90137,
#     90170,
#     90188,
#     90206,
#     90209,
#     90248,
#     90263,
#     90269,
#     90290,
#     90386,
#     90404,
#     90428,
#     90461,
#     90515,
#     90533,
#     90560,
#     90566,
#     90581,
#     90677,
#     89858,
#     89909,
#     89960,
#     89981,
#     90131,
#     90173,
#     90200,
#     90212,
#     90320,
#     90353,
#     90401,
#     90431,
#     90449,
#     90452,
#     90455,
#     90470,
#     90488,
#     90554,
#     90656,
#     90665,
#     90698,
#     90719,
#     89867,
#     89870,
#     89873,
#     89888,
#     89894,
#     89903,
#     89915,
#     89969,
#     90020,
#     90032,
#     90089,
#     90158,
#     90161,
#     90272,
#     90362,
#     90410,
#     90518,
#     90614,
#     90626,
#     90662,
#     89948,
#     90035,
#     90194,
#     90299,
#     90314,
#     90341,
#     90344,
#     90380,
#     90422,
#     90434,
#     90446,
#     90491,
#     90506,
#     90716,
#     89954,
#     89975,
#     89999,
#     90059,
#     90233,
#     90242,
#     90260,
#     90332,
#     90419,
#     90485,
#     90494,
#     90527,
#     90563,
#     90683,
#     90689,
#     89882,
#     89963,
#     90044,
#     90098,
#     90539,
#     90569,
#     90224,
#     90308,
#     90545,
#     90623,
#     90707,
#     89996,
#     90221,
#     90245,
#     90350,
#     90383,
#     90464,
#     90620,
#     89897,
#     89921,
#     90071,
#     90149,
#     90254,
#     90335,
#     90368,
#     90395,
#     90548,
#     90557,
#     90038,
#     90080,
#     90095,
#     90107,
#     90140,
#     90176,
#     90293,
#     89966,
#     90152,
#     90179,
#     90359,
#     90437,
#     90503,
#     90542,
#     90584,
#     90302,
#     90413,
#     90509,
#     90671,
#     90500,
#     89912,
#     89978,
#     90185,
#     90197,
#     90587,
#     90305,
#     90011,
#     90218,
#     89984,
#     90065,
#     89939,
#     90191,
#     90647,
#     90143,
#     90251,
#     90686,
#     90029,
#     90326,
#     90725,
#     89864]},
#   {'rank': 3,
#    'name': 'Cluster 3',
#    'score': 36.401826484018265,
#    'seedNode': 90416,
#    'nodes': [90050,
#     90722,
#     90629,
#     90407,
#     90575,
#     90416,
#     90068,
#     90425,
#     90713,
#     90680,
#     90266,
#     90398,
#     90110,
#     89870,
#     89885,
#     89897,
#     89975,
#     89981,
#     90074,
#     90104,
#     90161,
#     90179,
#     90182,
#     90224,
#     90227,
#     90233,
#     90245,
#     90257,
#     90260,
#     90275,
#     90284,
#     90287,
#     90296,
#     90305,
#     90329,
#     90347,
#     90362,
#     90368,
#     90374,
#     90380,
#     90392,
#     90473,
#     90503,
#     90518,
#     90521,
#     90548,
#     90551,
#     90569,
#     90602,
#     90608,
#     90611,
#     90620,
#     90635,
#     90656,
#     90671,
#     90677,
#     90710,
#     89858,
#     89963,
#     90038,
#     90071,
#     90131,
#     90140,
#     90200,
#     90236,
#     90251,
#     90302,
#     90467,
#     90509,
#     90614,
#     90632,
#     90665,
#     89876,
#     89936,
#     89945,
#     89948,
#     89966,
#     89984,
#     89996,
#     90011,
#     90065,
#     90083,
#     90086,
#     90107,
#     90209,
#     90281,
#     90290,
#     90293,
#     90308,
#     90320,
#     90326,
#     90353,
#     90359,
#     90371,
#     90386,
#     90413,
#     90428,
#     90458,
#     90464,
#     90488,
#     90515,
#     90530,
#     90533,
#     90545,
#     90554,
#     90641,
#     90653,
#     90674,
#     90704,
#     90707,
#     89873,
#     89879,
#     89900,
#     89912,
#     89918,
#     89924,
#     89951,
#     89990,
#     90008,
#     90047,
#     90146,
#     90164,
#     90410,
#     90419,
#     90566,
#     90578,
#     90662,
#     90686,
#     89894,
#     89903,
#     90020,
#     90026,
#     90125,
#     90149,
#     90323,
#     90335,
#     90350,
#     90434,
#     90449,
#     90455,
#     90476,
#     90539,
#     90572,
#     90623,
#     90668,
#     90716,
#     89882,
#     89891,
#     89915,
#     89927,
#     90017,
#     90029,
#     90167,
#     90314,
#     90389,
#     90443,
#     90524,
#     90593,
#     90617,
#     89960,
#     90041,
#     90092,
#     90101,
#     90155,
#     90248,
#     90446,
#     90452,
#     90599,
#     90647,
#     90659,
#     90695,
#     90719,
#     89930,
#     89987,
#     90098,
#     90116,
#     90170,
#     90206,
#     90221,
#     90341,
#     90479,
#     90557,
#     90587,
#     90701,
#     90725,
#     89861,
#     89909,
#     89957,
#     89993,
#     90005,
#     90053,
#     90062,
#     90215,
#     90263,
#     90356,
#     90395,
#     90494,
#     90512,
#     89921,
#     90254,
#     90338,
#     90644,
#     89933,
#     90044,
#     90095,
#     90278,
#     90317,
#     90440,
#     89978,
#     90197,
#     90203,
#     90218,
#     90383,
#     90527,
#     90542,
#     90581,
#     89888,
#     90269,
#     90605,
#     90683]},
#   {'rank': 4,
#    'name': 'Cluster 4',
#    'score': 30.9025641025641,
#    'seedNode': 90383,
#    'nodes': [90368,
#     90245,
#     89993,
#     89864,
#     89867,
#     89996,
#     90383,
#     90128,
#     90131,
#     90260,
#     90263,
#     90011,
#     90269,
#     90146,
#     89894,
#     90278,
#     90281,
#     90665,
#     90155,
#     89900,
#     90671,
#     90164,
#     90038,
#     90170,
#     90557,
#     90428,
#     90431,
#     90560,
#     90563,
#     90311,
#     90569,
#     90320,
#     89939,
#     90194,
#     90071,
#     90455,
#     90716,
#     90335,
#     90206,
#     90212,
#     90470,
#     90089,
#     90605,
#     90095,
#     90350,
#     90353,
#     90224,
#     90101,
#     89972,
#     89975,
#     90230,
#     90614,
#     90107,
#     90491,
#     90362,
#     90623,
#     90494,
#     89870,
#     89882,
#     89888,
#     89897,
#     89960,
#     89969,
#     89984,
#     90080,
#     90098,
#     90140,
#     90158,
#     90179,
#     90200,
#     90251,
#     90272,
#     90314,
#     90395,
#     90404,
#     90587,
#     90647,
#     90689,
#     90707,
#     89903,
#     89933,
#     90029,
#     90065,
#     90134,
#     90449,
#     90503,
#     90554,
#     90566,
#     90656,
#     90677,
#     89909,
#     90017,
#     90149,
#     90185,
#     90305,
#     90308,
#     90344,
#     90380,
#     90437,
#     90446,
#     90458,
#     90500,
#     90506,
#     90509,
#     90698,
#     89921,
#     89963,
#     89978,
#     89981,
#     90008,
#     90161,
#     90173,
#     90176,
#     90197,
#     90203,
#     90236,
#     90248,
#     90422,
#     90521,
#     90584,
#     90590,
#     90662,
#     90725,
#     89912,
#     90059,
#     90143,
#     90434,
#     90518,
#     90539,
#     90542,
#     90548,
#     90626,
#     90683,
#     89873,
#     89927,
#     89936,
#     89999,
#     90032,
#     90077,
#     90242,
#     90359,
#     90386,
#     90581,
#     90719,
#     89858,
#     89879,
#     90299,
#     90419,
#     90464,
#     90479,
#     90527,
#     89915,
#     89957,
#     90188,
#     90191,
#     90302,
#     90317,
#     90410,
#     90467,
#     90686,
#     90044,
#     90233,
#     90326,
#     90452,
#     90485,
#     90488,
#     90047,
#     90254,
#     90440,
#     90002,
#     90020,
#     90152,
#     90401,
#     90620,
#     89930,
#     89966,
#     90218,
#     90533,
#     90545,
#     90137,
#     90221,
#     90332,
#     90374,
#     90515,
#     89942,
#     89948,
#     90461,
#     90341,
#     90413,
#     89885,
#     90551,
#     89954,
#     90290,
#     90209,
#     90293,
#     90035]},
#   {'rank': 5,
#    'name': 'Cluster 5',
#    'score': 22.89051094890511,
#    'seedNode': 90698,
#    'nodes': [90305,
#     89984,
#     90179,
#     89927,
#     90374,
#     90059,
#     90251,
#     89930,
#     90506,
#     90698,
#     90254,
#     90515,
#     90707,
#     90002,
#     90197,
#     90647,
#     90137,
#     90521,
#     90008,
#     90203,
#     90458,
#     90077,
#     90527,
#     90017,
#     90656,
#     89954,
#     90404,
#     90662,
#     89897,
#     90344,
#     89963,
#     90413,
#     90545,
#     90035,
#     90419,
#     90290,
#     90293,
#     90551,
#     90683,
#     90554,
#     90173,
#     90047,
#     90686,
#     89873,
#     89936,
#     89957,
#     90065,
#     90161,
#     90218,
#     90221,
#     90248,
#     90314,
#     90341,
#     90410,
#     90467,
#     90479,
#     90488,
#     90509,
#     90548,
#     90626,
#     89879,
#     89882,
#     89888,
#     89915,
#     89942,
#     89999,
#     90029,
#     90098,
#     90188,
#     90191,
#     90209,
#     90308,
#     90332,
#     90386,
#     90401,
#     90461,
#     90464,
#     90539,
#     90581,
#     90725,
#     89903,
#     89978,
#     90020,
#     90158,
#     90437,
#     90452,
#     90542,
#     90584,
#     89858,
#     89885,
#     89933,
#     90080,
#     90434,
#     90620,
#     90134,
#     90233,
#     90317,
#     90395,
#     90422,
#     90689,
#     90032,
#     90242,
#     90299,
#     90359,
#     90440,
#     90485,
#     90500,
#     90518,
#     90533,
#     90044,
#     90185,
#     90272,
#     90587,
#     89960,
#     90302,
#     90677,
#     90152,
#     90449,
#     90503,
#     90590,
#     89870,
#     89966,
#     89969,
#     90149,
#     90380,
#     90140,
#     90176,
#     90200,
#     90236,
#     90566,
#     90143,
#     89948,
#     89912,
#     89981,
#     90446,
#     89921,
#     90326,
#     89909]},
#   {'rank': 6,
#    'name': 'Cluster 6',
#    'score': 15.8494623655914,
#    'seedNode': 90590,
#    'nodes': [89858,
#     90242,
#     90626,
#     90308,
#     90500,
#     90248,
#     90314,
#     90509,
#     90188,
#     90380,
#     90191,
#     89870,
#     90386,
#     90452,
#     89879,
#     90134,
#     89942,
#     90200,
#     90395,
#     89882,
#     90140,
#     90332,
#     90143,
#     90590,
#     90209,
#     90080,
#     90272,
#     90464,
#     90467,
#     90533,
#     90725,
#     90029,
#     90098,
#     90485,
#     90677,
#     90548,
#     90359,
#     90422,
#     89915,
#     89978,
#     90236,
#     89903,
#     89921,
#     89948,
#     89969,
#     90317,
#     90446,
#     90449,
#     90566,
#     90620,
#     89873,
#     89960,
#     89966,
#     90158,
#     90434,
#     90440,
#     90689,
#     89936,
#     90152,
#     90479,
#     90503,
#     90020,
#     90176,
#     90185,
#     90218,
#     90233,
#     90326,
#     90401,
#     90437,
#     90584,
#     90587,
#     89909,
#     90581,
#     89885,
#     89888,
#     89981,
#     89999,
#     90149,
#     90410,
#     90542,
#     90065,
#     90221,
#     90341,
#     89912,
#     89957,
#     90518,
#     90161,
#     90302,
#     90044,
#     90299,
#     90539,
#     89933,
#     90461,
#     90488]},
#   {'rank': 7,
#    'name': 'Cluster 7',
#    'score': 9.692307692307693,
#    'seedNode': 90581,
#    'nodes': [90566,
#     90185,
#     90440,
#     89933,
#     90317,
#     89999,
#     90449,
#     90581,
#     90518,
#     90461,
#     89948,
#     90401,
#     89888,
#     89957,
#     90020,
#     90152,
#     90539,
#     90218,
#     90221,
#     90479,
#     90158,
#     89969,
#     90161,
#     89909,
#     90233,
#     90044,
#     90620,
#     89885,
#     89912,
#     89921,
#     90410,
#     90584,
#     90587,
#     89873,
#     89960,
#     89981,
#     90302,
#     90488,
#     89903,
#     90446,
#     90299,
#     90326,
#     90434,
#     90149,
#     89966,
#     89936,
#     90503,
#     90341,
#     90065,
#     90542,
#     90689,
#     90176,
#     90437]},
#   {'rank': 8,
#    'name': 'Cluster 8',
#    'score': 4.6,
#    'seedNode': 89903,
#    'nodes': [89921,
#     90689,
#     90434,
#     90503,
#     89960,
#     90410,
#     89903,
#     90542,
#     90065,
#     89936,
#     90326,
#     90584,
#     89885,
#     89981,
#     90302,
#     89966,
#     90341,
#     90488,
#     90437,
#     90587,
#     90299]}],
#  'stale': False,
#  'lock': {}}
